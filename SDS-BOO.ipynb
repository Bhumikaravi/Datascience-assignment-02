# %%
#DATSET FOR E-COMMERECE
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\BHUMIKA RAVI\OneDrive\Desktop\Fast Delivery Agent Reviews.csv")
df
# Out:
#      Agent Name  Rating                                        Review Text  \
# 0         Zepto     4.5  Purpose boy job cup decision girl now get job ...
# 1         Zepto     2.1  Prevent production able both the box school wa...
# 2       JioMart     4.5  Family station listen agreement more kitchen l...
# 3       JioMart     2.6  World north people area everything enter beyon...
# 4         Zepto     3.6  Hand way yourself tax whether sister anyone ef...
# ...         ...     ...                                                ...
# 4995    Blinkit     2.4  Assume president far economic us discuss hand ...
# 4996    JioMart     3.2  Chance new edge beyond pass treat laugh woman ...
# 4997      Zepto     4.7  Until few population choose value behavior win...
# 4998    JioMart     3.8  Fight where recently half enter information ki...
# 4999    JioMart     4.5  Agreement challenge boy coach low person these...
#
# ...

# %%
df.head(15)
# Out:
#           Agent Name  Rating  \
# 0              Zepto     4.5
# 1              Zepto     2.1
# 2            JioMart     4.5
# 3            JioMart     2.6
# 4              Zepto     3.6
# 5            Blinkit     1.9
# 6            Blinkit     3.3
# 7            Blinkit     1.5
# 8              Zepto     2.8
# 9            JioMart     2.5
# 10             Zepto     2.5
# 11  Swiggy Instamart     2.9
# 12           JioMart     4.6
# 13           JioMart     2.6
# 14           Blinkit     3.6
#
#                                           Review Text  Delivery Time (min)  \
# 0   Purpose boy job cup decision girl now get job ...                   58
# 1   Prevent production able both the box school wa...                   25
# 2   Family station listen agreement more kitchen l...                   54
# 3   World north people area everything enter beyon...                   22
# 4   Hand way yourself tax whether sister anyone ef...                   34
# ...

# %%
df.tail(20)
# Out:
#             Agent Name  Rating  \
# 4980           Blinkit     4.3
# 4981             Zepto     1.4
# 4982           Blinkit     2.4
# 4983           JioMart     2.4
# 4984             Zepto     1.4
# 4985           JioMart     4.7
# 4986             Zepto     2.4
# 4987           JioMart     2.3
# 4988           JioMart     3.5
# 4989             Zepto     1.4
# 4990  Swiggy Instamart     4.9
# 4991             Zepto     3.0
# 4992           JioMart     3.2
# 4993  Swiggy Instamart     3.6
# 4994           Blinkit     2.5
# 4995           Blinkit     2.4
# 4996           JioMart     3.2
# 4997             Zepto     4.7
# 4998           JioMart     3.8
# 4999           JioMart     4.5
#
#                                             Review Text  Delivery Time (min)  \
# 4980         Serve how wait within there four hand why.                   48
# 4981  Computer weight identify key hit full moment r...                   36
# ...

# %%
data.describe()
# Out:
#            Rating  Delivery Time (min)  Customer Service Rating
# count  5000.00000          5000.000000              5000.000000
# mean      3.00290            34.962400                 2.972000
# std       1.15214            14.789656                 1.409969
# min       1.00000            10.000000                 1.000000
# 25%       2.00000            22.000000                 2.000000
# 50%       3.00000            35.000000                 3.000000
# 75%       4.00000            48.000000                 4.000000
# max       5.00000            60.000000                 5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Agent Name               5000 non-null   object
#  1   Rating                   5000 non-null   float64
#  2   Review Text              5000 non-null   object
#  3   Delivery Time (min)      5000 non-null   int64
#  4   Location                 5000 non-null   object
#  5   Order Type               5000 non-null   object
#  6   Customer Feedback Type   5000 non-null   object
#  7   Price Range              5000 non-null   object
#  8   Discount Applied         5000 non-null   object
#  9   Product Availability     5000 non-null   object
#  10  Customer Service Rating  5000 non-null   int64
#  11  Order Accuracy           5000 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 468.9+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Agent Name  Rating                                        Review Text  \
# 0         Zepto     4.5  Purpose boy job cup decision girl now get job ...
# 1         Zepto     2.1  Prevent production able both the box school wa...
# 2       JioMart     4.5  Family station listen agreement more kitchen l...
# 3       JioMart     2.6  World north people area everything enter beyon...
# 4         Zepto     3.6  Hand way yourself tax whether sister anyone ef...
# ...         ...     ...                                                ...
# 4995    Blinkit     2.4  Assume president far economic us discuss hand ...
# 4996    JioMart     3.2  Chance new edge beyond pass treat laugh woman ...
# 4997      Zepto     4.7  Until few population choose value behavior win...
# 4998    JioMart     3.8  Fight where recently half enter information ki...
# 4999    JioMart     4.5  Agreement challenge boy coach low person these...
#
# ...

# %%
# Univariate Analysis: Numerical
sns.histplot(df['Rating'], kde=True).set_title('Rating distribution')
plt.show()

# %%
# Univariate Analysis: Numerical
sns.histplot(df['Customer Service Rating'], kde=True).set_title('Customer Service Rating distribution')
plt.show()

# %%
# Univariate Analysis: Numerical
sns.histplot(df['Product Availability'], kde=True).set_title('Product Availability Distribution')
plt.show()

# %%
# Univariate Analysis: Categorical
sns.countplot(x='Price Range', data=df).set_title('Price Range Count')
plt.show()

# %%
# Univariate Pie Chart: Price Range distribution
gender_counts = df['Price Range'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Price Range Distribution')
plt.show()

# %%
# Univariate Analysis: Categorical
sns.countplot(x='Order Type', data=df).set_title('Order Type Count')
plt.show()

# %%
# Univariate Pie Chart: Product Availability distribution
depression_counts = df['Product Availability'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(depression_counts, labels=['Not in stock', 'Stock'], autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon'])
plt.title('Product Availability Distribution')
plt.show()

# %%
# Univariate Analysis: Categorical
sns.countplot(x='Customer Feedback Type', data=df).set_title('Customer Feedback Type distribution')
plt.show()

# %%
# Univariate Pie Chart:Customer Feedback Type
diet_counts = df['Customer Feedback Type'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(diet_counts, labels=diet_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Customer Feedback Type Distribution')
plt.show()

# %%
#Agent Name vs Rating by scaatter plot
sns.scatterplot(x='Agent Name', y='Rating',hue='Order Type',  data=df, alpha=0.8)
plt.title('Agent Name vs Rating')
plt.xlabel('Agent Name')
plt.ylabel('Rating')
plt.grid(True)
plt.show()

# %%
# Scatter plot colored by agent name vs Price Range
sns.scatterplot(x='Agent Name', y='Price Range', hue='Rating', data=df, alpha=0.7)
plt.title('agent name vs Price Range')
plt.xlabel('Agent Name')
plt.ylabel('Price Range')
plt.grid(True)
plt.show()

# %%
#Agent name vs Rating scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['Agent Name'], df['Rating'], color='teal', alpha=0.5)
plt.title('Agent name vs Rating')
plt.xlabel('Agent Name')
plt.ylabel('Rating')
plt.grid(True)
plt.show()

# %%
sns.countplot(x='Discount Applied', hue='Price Range', data=df)
plt.title('Discount Applied by Price Range ')
plt.show()

# %%
#Bivariate rating vs location
sns.boxplot(x='Rating', y='Location',hue='Price Range', data=df)
plt.title('Rating by location')
plt.show()

# %%
# Scatter Plot (Bivariate):  colored by Product Availability
sns.scatterplot(x='Location', y='Rating', hue='Product Availability', data=df, alpha=0.9)
plt.title('Location vs rating')
plt.xlabel('Location')
plt.ylabel('Rating')
plt.grid(True)
plt.show()

# %%
# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['Agent Name'], df['Location'], alpha=0.6, c='purple')
plt.title('agent name vs location')
plt.xlabel('Agent Name')
plt.ylabel('Location')
plt.grid(True)
plt.show()

# %%
# Pairplot with Price Range hue  Multivariate Analysis
selected_columns = ['Delivery Time (min)','Rating','Customer Service Rating','Price Range']
sns.pairplot(df[selected_columns], hue='Price Range')
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()

# %%
# Correlation Heatmap
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
